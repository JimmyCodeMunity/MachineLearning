# %%
import yfinance as yf
import pandas as pd

# %% [markdown]
# set the start and end date

# %%
start_date = '2023-01-01'
end_date = '2023-01-31'

# %% [markdown]
# Setting the ticker

# %%
ticker = 'AMZN'

# %% [markdown]
# Get the data

# %%
data = yf.download(ticker, start_date,end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# Print all the rows

# %%
data.tail()
# Out:
#                   Open        High        Low       Close   Adj Close  \
# Date
# 2023-01-24   96.930000   98.089996  96.000000   96.320000   96.320000
# 2023-01-25   92.559998   97.239998  91.519997   97.180000   97.180000
# 2023-01-26   98.239998   99.489998  96.919998   99.220001   99.220001
# 2023-01-27   99.529999  103.489998  99.529999  102.239998  102.239998
# 2023-01-30  101.089996  101.739998  99.010002  100.550003  100.550003
#
#               Volume
# Date
# 2023-01-24  66929500
# 2023-01-25  94261600
# 2023-01-26  68523600
# 2023-01-27  87678100
# 2023-01-30  70691900

# %% [markdown]
# import matplotlib for plotting

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# plot adjusted close price data

# %%
data['Adj Close'].plot()
plt.show()

# %% [markdown]
# plot adjusted close price

# %%
data['Adj Close'].plot(figsize=(10,7))

#define the label for the title
plt.title("Adjusted Close Price of %s" % ticker, fontsize=16)

#define the labels fro x-axis and y-axis
plt.ylabel('Price', fontsize=14)
plt.xlabel('Year',fontsize=14)

#plot the gridlines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)

#display the plot
plt.show()

# %%
import pandas as pd

writer = pd.ExcelWriter('stocks.xlsx', engine='xlsxwriter')

data.to_excel(writer, sheet_name='MarketStock')

writer.save()
# Out:
# /tmp/ipykernel_4160/4040691406.py:7: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
